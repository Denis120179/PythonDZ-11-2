# %%
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
# Определить корни
# Найти интервалы, на которых функция возрастает
# Найти интервалы, на которых функция убывает
# Построить график
# Вычислить вершину
# Определить промежутки, на котором f > 0
# Определить промежутки, на котором f < 0

# %%
import pandas as pd

# %%
from sympy import*

# %%
from math import*

# %%
x = symbols("x")

# %%
y = -5*x**2 + 10*x - 150

# %%
roots = solve(y,x)

# %%
roots
# Out:
# [1 - sqrt(29)*I, 1 + sqrt(29)*I]

# %%
fd = diff(y,x)

# %%
solve(0<y) # нет значений х, где y > 0
# Out:
# False

# %%
solve(y<0) # при любых значениях х y < 0
# Out:
# (-oo < x) & (x < oo)

# %%
from matplotlib import pyplot

# %%
x = list(range(-20, 20))

# %%
y = [-5*i**2 + 10*i - 150 for i in x ]

# %%
f = pyplot.plot(x, y)

# %%
solve(fd)
# Out:
# [1]
